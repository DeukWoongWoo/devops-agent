# %%
# !curl -vvv -X POST http://localhost:8000/terraform-agent \
  -H "Content-Type: application/json" \
  -d '{"user_id": "dw.woo", "user_input": "hi"}'
# Out:
# Note: Unnecessary use of -X or --request, POST is already inferred.
# 19:25:13.834451 [0-x] == Info: [READ] client_reset, clear readers
# 19:25:13.834640 [0-0] == Info: Host localhost:8000 was resolved.
# 19:25:13.834674 [0-0] == Info: IPv6: ::1
# 19:25:13.834697 [0-0] == Info: IPv4: 127.0.0.1
# 19:25:13.834724 [0-0] == Info: [SETUP] added
# 19:25:13.834783 [0-0] == Info:   Trying [::1]:8000...
# 19:25:13.834865 [0-0] == Info: [SETUP] Curl_conn_connect(block=0) -> 0, done=0
# 19:25:13.834924 [0-0] == Info: connect to ::1 port 8000 from ::1 port 51161 failed: Connection refused
# 19:25:13.834991 [0-0] == Info:   Trying 127.0.0.1:8000...
# 19:25:13.835050 [0-0] == Info: [SETUP] Curl_conn_connect(block=0) -> 0, done=0
# 19:25:13.835179 [0-0] == Info: [SETUP] Curl_conn_connect(block=0) -> 0, done=1
# 19:25:13.835220 [0-0] == Info: Connected to localhost (127.0.0.1) port 8000
# 19:25:13.835259 [0-0] == Info: using HTTP/1.x
# ...
